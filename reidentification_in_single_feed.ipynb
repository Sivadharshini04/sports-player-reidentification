# %%
import torch
from ultralytics import YOLO
import cv2
import numpy as np
from torchvision import models, transforms
from scipy.spatial.distance import cosine
from tqdm import tqdm
import os

# %%
#device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
#load pretrained model best.pt
model = YOLO(r'D:\Liat_ai\best.pt')  

#load resnet18 feature extractor
resnet = models.resnet18(pretrained=True)
resnet.fc = torch.nn.Identity()
resnet = resnet.to(device).eval()

#transform functions
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((128, 64)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
# Out:
# C:\Users\ssiva\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\ssiva\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#detection function
def detect_players(frame):
    results = model(frame)[0]
    detections = []
    for box in results.boxes:
        cls_id = int(box.cls.item())
        conf = float(box.conf.item())
        if conf > 0.5:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            detections.append((x1, y1, x2, y2, conf))
    return detections

# %%
player_embeddings = {}
next_player_id = 0
SIMILARITY_THRESHOLD = 0.6

#input video
cap = cv2.VideoCapture(r'D:\Liat_ai\15sec_input_720p.mp4')
if not cap.isOpened():
    raise ValueError("Error: video not opened!")

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

#output video
out = cv2.VideoWriter(r'D:\Liat_ai\output.mp4',
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      fps, (width, height))

# %%
#frame by frame reidentification
frame_num = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break

    detections = detect_players(frame)
    current_frame_ids = []

    for (x1, y1, x2, y2, conf) in detections:
        crop = frame[y1:y2, x1:x2]
        if crop.size == 0:
            continue

        input_tensor = transform(crop).unsqueeze(0).to(device)
        with torch.no_grad():
            feature = resnet(input_tensor).squeeze().cpu().numpy()

        
        best_pid = None
        best_similarity = 1

        for pid, prev_feat in player_embeddings.items():
            similarity = cosine(prev_feat, feature)
            if similarity < best_similarity:
                best_similarity = similarity
                best_pid = pid

        if best_similarity < SIMILARITY_THRESHOLD:
            current_frame_ids.append((x1, y1, x2, y2, best_pid))
            player_embeddings[best_pid] = feature
        else:
            player_embeddings[next_player_id] = feature
            current_frame_ids.append((x1, y1, x2, y2, next_player_id))
            next_player_id += 1

    
    for (x1, y1, x2, y2, pid) in current_frame_ids:
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
        cv2.putText(frame, f'Player {pid}', (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2)

    out.write(frame)
    frame_num += 1
    if frame_num % 10 == 0:
        print(f"Processed {frame_num} frames...")

cap.release()
out.release()
print("Video saved.")
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 804.2ms
# Speed: 5.4ms preprocess, 804.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 880.3ms
# Speed: 2.1ms preprocess, 880.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 716.6ms
# Speed: 1.9ms preprocess, 716.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 792.9ms
# Speed: 1.8ms preprocess, 792.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 755.1ms
# Speed: 1.7ms preprocess, 755.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1153.0ms
# Speed: 1.8ms preprocess, 1153.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1294.8ms
# Speed: 3.1ms preprocess, 1294.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 688.2ms
# Speed: 1.9ms preprocess, 688.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 695.1ms
# Speed: 1.5ms preprocess, 695.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 777.3ms
# Speed: 1.5ms preprocess, 777.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 10 frames...
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1227.2ms
# Speed: 2.9ms preprocess, 1227.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 927.2ms
# Speed: 2.5ms preprocess, 927.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 744.0ms
# Speed: 3.9ms preprocess, 744.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 717.5ms
# Speed: 1.5ms preprocess, 717.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 742.2ms
# Speed: 1.7ms preprocess, 742.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 829.5ms
# Speed: 1.6ms preprocess, 829.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 744.5ms
# Speed: 1.8ms preprocess, 744.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 725.3ms
# Speed: 1.5ms preprocess, 725.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 815.2ms
# Speed: 1.7ms preprocess, 815.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1213.4ms
# Speed: 2.7ms preprocess, 1213.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 20 frames...
#
# 0: 384x640 14 players, 1 referee, 1178.4ms
# Speed: 3.6ms preprocess, 1178.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 1258.7ms
# Speed: 2.2ms preprocess, 1258.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1262.2ms
# Speed: 2.4ms preprocess, 1262.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1220.5ms
# Speed: 4.7ms preprocess, 1220.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 754.0ms
# Speed: 1.6ms preprocess, 754.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 750.1ms
# Speed: 2.1ms preprocess, 750.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 821.7ms
# Speed: 2.5ms preprocess, 821.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 1256.5ms
# Speed: 2.8ms preprocess, 1256.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2 referees, 803.4ms
# Speed: 2.7ms preprocess, 803.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 16 players, 2 referees, 752.6ms
# Speed: 1.6ms preprocess, 752.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed 30 frames...
#
# 0: 384x640 2 balls, 15 players, 2 referees, 690.0ms
# Speed: 2.1ms preprocess, 690.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1079.7ms
# Speed: 1.7ms preprocess, 1079.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1264.0ms
# Speed: 4.1ms preprocess, 1264.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1198.6ms
# Speed: 2.5ms preprocess, 1198.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1154.4ms
# Speed: 2.5ms preprocess, 1154.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3 referees, 701.7ms
# Speed: 3.1ms preprocess, 701.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 716.0ms
# Speed: 1.8ms preprocess, 716.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1298.4ms
# Speed: 3.3ms preprocess, 1298.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1219.2ms
# Speed: 2.1ms preprocess, 1219.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 749.5ms
# Speed: 2.9ms preprocess, 749.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed 40 frames...
#
# 0: 384x640 1 ball, 17 players, 3 referees, 729.5ms
# Speed: 1.6ms preprocess, 729.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 741.8ms
# Speed: 1.5ms preprocess, 741.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1183.3ms
# Speed: 1.8ms preprocess, 1183.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1176.6ms
# Speed: 2.1ms preprocess, 1176.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 1196.9ms
# Speed: 3.3ms preprocess, 1196.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 899.4ms
# Speed: 4.4ms preprocess, 899.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 680.4ms
# Speed: 1.4ms preprocess, 680.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1185.6ms
# Speed: 2.3ms preprocess, 1185.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1206.0ms
# Speed: 2.8ms preprocess, 1206.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 901.3ms
# Speed: 2.1ms preprocess, 901.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed 50 frames...
#
# 0: 384x640 16 players, 2 referees, 706.2ms
# Speed: 1.8ms preprocess, 706.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 768.6ms
# Speed: 2.1ms preprocess, 768.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1219.2ms
# Speed: 2.8ms preprocess, 1219.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 1122.6ms
# Speed: 2.0ms preprocess, 1122.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 900.6ms
# Speed: 1.9ms preprocess, 900.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 801.2ms
# Speed: 2.9ms preprocess, 801.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 704.8ms
# Speed: 1.9ms preprocess, 704.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 1084.0ms
# Speed: 1.7ms preprocess, 1084.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1170.8ms
# Speed: 2.5ms preprocess, 1170.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1196.6ms
# Speed: 2.4ms preprocess, 1196.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed 60 frames...
#
# 0: 384x640 1 ball, 14 players, 2 referees, 679.6ms
# Speed: 1.8ms preprocess, 679.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 739.8ms
# Speed: 1.9ms preprocess, 739.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 941.1ms
# Speed: 1.9ms preprocess, 941.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1203.5ms
# Speed: 2.6ms preprocess, 1203.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 946.5ms
# Speed: 2.1ms preprocess, 946.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 4 referees, 870.2ms
# Speed: 1.3ms preprocess, 870.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 761.9ms
# Speed: 3.9ms preprocess, 761.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 4 referees, 899.8ms
# Speed: 1.8ms preprocess, 899.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1182.5ms
# Speed: 4.2ms preprocess, 1182.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 739.0ms
# Speed: 1.8ms preprocess, 739.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 70 frames...
#
# 0: 384x640 1 ball, 14 players, 2 referees, 929.3ms
# Speed: 2.7ms preprocess, 929.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 861.6ms
# Speed: 2.0ms preprocess, 861.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 862.6ms
# Speed: 2.2ms preprocess, 862.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1085.8ms
# Speed: 2.9ms preprocess, 1085.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 968.4ms
# Speed: 2.3ms preprocess, 968.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 763.7ms
# Speed: 2.4ms preprocess, 763.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1078.0ms
# Speed: 2.5ms preprocess, 1078.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 936.0ms
# Speed: 1.4ms preprocess, 936.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 802.9ms
# Speed: 3.3ms preprocess, 802.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1049.6ms
# Speed: 2.7ms preprocess, 1049.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed 80 frames...
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1014.8ms
# Speed: 1.7ms preprocess, 1014.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 787.4ms
# Speed: 1.8ms preprocess, 787.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1001.3ms
# Speed: 2.0ms preprocess, 1001.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 946.1ms
# Speed: 2.0ms preprocess, 946.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 822.3ms
# Speed: 2.6ms preprocess, 822.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1066.1ms
# Speed: 2.0ms preprocess, 1066.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 969.7ms
# Speed: 1.4ms preprocess, 969.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 876.0ms
# Speed: 2.6ms preprocess, 876.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1112.6ms
# Speed: 2.0ms preprocess, 1112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 955.3ms
# Speed: 1.9ms preprocess, 955.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 90 frames...
#
# 0: 384x640 1 ball, 16 players, 1 referee, 906.8ms
# Speed: 2.7ms preprocess, 906.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 1213.1ms
# Speed: 4.5ms preprocess, 1213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 781.6ms
# Speed: 3.1ms preprocess, 781.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 844.7ms
# Speed: 1.5ms preprocess, 844.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 1052.9ms
# Speed: 2.6ms preprocess, 1052.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 907.2ms
# Speed: 1.5ms preprocess, 907.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1192.0ms
# Speed: 2.2ms preprocess, 1192.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 722.6ms
# Speed: 1.5ms preprocess, 722.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 1023.8ms
# Speed: 1.5ms preprocess, 1023.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees,
4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 190 frames...
#
# 0: 384x640 1 ball, 12 players, 1 referee, 974.8ms
# Speed: 2.2ms preprocess, 974.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1143.8ms
# Speed: 1.9ms preprocess, 1143.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1098.0ms
# Speed: 2.6ms preprocess, 1098.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 14 players, 943.7ms
# Speed: 3.3ms preprocess, 943.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1127.3ms
# Speed: 3.3ms preprocess, 1127.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1120.4ms
# Speed: 2.3ms preprocess, 1120.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 845.1ms
# Speed: 1.7ms preprocess, 845.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1073.2ms
# Speed: 2.5ms preprocess, 1073.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1014.2ms
# Speed: 1.7ms preprocess, 1014.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 835.8ms
# Speed: 2.1ms preprocess, 835.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 200 frames...
#
# 0: 384x640 1 ball, 14 players, 1044.4ms
# Speed: 2.8ms preprocess, 1044.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1036.1ms
# Speed: 1.7ms preprocess, 1036.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 850.8ms
# Speed: 2.0ms preprocess, 850.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1015.3ms
# Speed: 1.8ms preprocess, 1015.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 1057.0ms
# Speed: 1.6ms preprocess, 1057.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 869.2ms
# Speed: 4.0ms preprocess, 869.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1059.5ms
# Speed: 3.2ms preprocess, 1059.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1015.8ms
# Speed: 2.5ms preprocess, 1015.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 831.9ms
# Speed: 2.4ms preprocess, 831.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1054.0ms
# Speed: 3.4ms preprocess, 1054.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 210 frames...
#
# 0: 384x640 13 players, 923.0ms
# Speed: 1.5ms preprocess, 923.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 906.2ms
# Speed: 2.7ms preprocess, 906.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1092.6ms
# Speed: 2.6ms preprocess, 1092.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1170.0ms
# Speed: 3.3ms preprocess, 1170.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 10 players, 816.0ms
# Speed: 2.3ms preprocess, 816.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1108.2ms
# Speed: 2.3ms preprocess, 1108.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 967.0ms
# Speed: 4.7ms preprocess, 967.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 889.9ms
# Speed: 1.4ms preprocess, 889.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1265.6ms
# Speed: 2.0ms preprocess, 1265.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 973.3ms
# Speed: 1.5ms preprocess, 973.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 220 frames...
#
# 0: 384x640 9 players, 1196.0ms
# Speed: 2.3ms preprocess, 1196.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1192.9ms
# Speed: 2.4ms preprocess, 1192.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 838.9ms
# Speed: 1.8ms preprocess, 838.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1352.2ms
# Speed: 2.1ms preprocess, 1352.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1052.5ms
# Speed: 2.8ms preprocess, 1052.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 845.8ms
# Speed: 1.6ms preprocess, 845.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 9 players, 1253.4ms
# Speed: 2.4ms preprocess, 1253.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 788.7ms
# Speed: 1.5ms preprocess, 788.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1213.1ms
# Speed: 3.5ms preprocess, 1213.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 959.1ms
# Speed: 2.2ms preprocess, 959.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed 230 frames...
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1151.5ms
# Speed: 1.9ms preprocess, 1151.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1239.4ms
# Speed: 2.3ms preprocess, 1239.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 721.6ms
# Speed: 2.0ms preprocess, 721.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 8 players, 1144.2ms
# Speed: 2.0ms preprocess, 1144.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1288.7ms
# Speed: 4.3ms preprocess, 1288.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 803.7ms
# Speed: 2.5ms preprocess, 803.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1194.2ms
# Speed: 2.0ms preprocess, 1194.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 973.0ms
# Speed: 3.7ms preprocess, 973.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1141.4ms
# Speed: 2.1ms preprocess, 1141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1102.6ms
# Speed: 2.7ms preprocess, 1102.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed 240 frames...
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1035.0ms
# Speed: 2.3ms preprocess, 1035.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 1258.6ms
# Speed: 3.3ms preprocess, 1258.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 1021.1ms
# Speed: 4.8ms preprocess, 1021.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1040.7ms
# Speed: 1.8ms preprocess, 1040.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 855.6ms
# Speed: 2.2ms preprocess, 855.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 1187.6ms
# Speed: 2.1ms preprocess, 1187.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1084.0ms
# Speed: 2.3ms preprocess, 1084.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1059.7ms
# Speed: 1.4ms preprocess, 1059.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 931.7ms
# Speed: 3.8ms preprocess, 931.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1190.0ms
# Speed: 2.3ms preprocess, 1190.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 250 frames...
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 943.7ms
# Speed: 4.2ms preprocess, 943.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1176.5ms
# Speed: 2.6ms preprocess, 1176.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1138.2ms
# Speed: 3.4ms preprocess, 1138.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 984.7ms
# Speed: 2.0ms preprocess, 984.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 911.1ms
# Speed: 3.1ms preprocess, 911.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 998.2ms
# Speed: 2.9ms preprocess, 998.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1321.1ms
# Speed: 3.5ms preprocess, 1321.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 761.5ms
# Speed: 4.9ms preprocess, 761.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1247.0ms
# Speed: 2.5ms preprocess, 1247.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1037.1ms
# Speed: 3.4ms preprocess, 1037.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 260 frames...
#
# 0: 384x640 1 goalkeeper, 9 players, 1327.7ms
# Speed: 2.5ms preprocess, 1327.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1044.5ms
# Speed: 3.1ms preprocess, 1044.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1108.0ms
# Speed: 1.9ms preprocess, 1108.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1007.3ms
# Speed: 2.0ms preprocess, 1007.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1051.6ms
# Speed: 2.1ms preprocess, 1051.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1184.4ms
# Speed: 2.1ms preprocess, 1184.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 873.5ms
# Speed: 3.1ms preprocess, 873.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1140.9ms
# Speed: 3.2ms preprocess, 1140.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1135.2ms
# Speed: 2.1ms preprocess, 1135.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1218.2ms
# Speed: 4.0ms preprocess, 1218.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 270 frames...
#
# 0: 384x640 1 goalkeeper, 8 players, 1164.0ms
# Speed: 2.7ms preprocess, 1164.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1284.3ms
# Speed: 3.8ms preprocess, 1284.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1289.3ms
# Speed: 2.2ms preprocess, 1289.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1255.9ms
# Speed: 7.4ms preprocess, 1255.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1275.9ms
# Speed: 4.6ms preprocess, 1275.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1306.0ms
# Speed: 4.4ms preprocess, 1306.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1380.3ms
# Speed: 3.2ms preprocess, 1380.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1342.0ms
# Speed: 4.0ms preprocess, 1342.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1263.0ms
# Speed: 3.0ms preprocess, 1263.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1312.7ms
# Speed: 3.2ms preprocess, 1312.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed 280 frames...
#
# 0: 384x640 14 players, 2019.1ms
# Speed: 3.1ms preprocess, 2019.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1985.0ms
# Speed: 5.0ms preprocess, 1985.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2014.8ms
# Speed: 2.9ms preprocess, 2014.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1555.2ms
# Speed: 3.6ms preprocess, 1555.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1479.1ms
# Speed: 2.8ms preprocess, 1479.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1429.8ms
# Speed: 2.5ms preprocess, 1429.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1387.4ms
# Speed: 3.8ms preprocess, 1387.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1503.2ms
# Speed: 3.2ms preprocess, 1503.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1247.0ms
# Speed: 2.8ms preprocess, 1247.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1433.8ms
# Speed: 5.1ms preprocess, 1433.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 290 frames...
#
# 0: 384x640 1 goalkeeper, 9 players, 1591.4ms
# Speed: 2.6ms preprocess, 1591.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1431.9ms
# Speed: 3.1ms preprocess, 1431.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1406.5ms
# Speed: 2.8ms preprocess, 1406.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1864.8ms
# Speed: 3.1ms preprocess, 1864.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2068.0ms
# Speed: 4.6ms preprocess, 2068.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1727.5ms
# Speed: 3.8ms preprocess, 1727.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1878.1ms
# Speed: 3.1ms preprocess, 1878.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1626.5ms
# Speed: 2.0ms preprocess, 1626.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1485.4ms
# Speed: 3.0ms preprocess, 1485.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1496.8ms
# Speed: 3.5ms preprocess, 1496.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 300 frames...
#
# 0: 384x640 1 goalkeeper, 15 players, 1652.3ms
# Speed: 3.1ms preprocess, 1652.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1465.0ms
# Speed: 2.3ms preprocess, 1465.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1366.1ms
# Speed: 3.6ms preprocess, 1366.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1295.1ms
# Speed: 2.9ms preprocess, 1295.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1235.8ms
# Speed: 3.4ms preprocess, 1235.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1255.8ms
# Speed: 3.2ms preprocess, 1255.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1243.5ms
# Speed: 4.5ms preprocess, 1243.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1019.7ms
# Speed: 3.3ms preprocess, 1019.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 795.5ms
# Speed: 1.6ms preprocess, 795.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1195.2ms
# Speed: 2.1ms preprocess, 1195.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 310 frames...
#
# 0: 384x640 1 goalkeeper, 15 players, 1074.1ms
# Speed: 2.0ms preprocess, 1074.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1246.7ms
# Speed: 2.1ms preprocess, 1246.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1124.6ms
# Speed: 1.9ms preprocess, 1124.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1240.8ms
# Speed: 3.1ms preprocess, 1240.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 954.3ms
# Speed: 2.7ms preprocess, 954.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1111.8ms
# Speed: 1.8ms preprocess, 1111.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 876.4ms
# Speed: 1.4ms preprocess, 876.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1114.1ms
# Speed: 2.7ms preprocess, 1114.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 1262.4ms
# Speed: 2.4ms preprocess, 1262.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 859.8ms
# Speed: 2.1ms preprocess, 859.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 320 frames...
#
# 0: 384x640 12 players, 977.9ms
# Speed: 2.9ms preprocess, 977.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1114.1ms
# Speed: 2.1ms preprocess, 1114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 958.5ms
# Speed: 1.9ms preprocess, 958.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 982.2ms
# Speed: 3.3ms preprocess, 982.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1010.2ms
# Speed: 1.5ms preprocess, 1010.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 924.1ms
# Speed: 4.0ms preprocess, 924.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1051.5ms
# Speed: 3.9ms preprocess, 1051.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1030.1ms
# Speed: 3.0ms preprocess, 1030.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 815.8ms
# Speed: 2.9ms preprocess, 815.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1152.1ms
# Speed: 3.1ms preprocess, 1152.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed 330 frames...
#
# 0: 384x640 12 players, 1086.3ms
# Speed: 2.4ms preprocess, 1086.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 946.1ms
# Speed: 3.4ms preprocess, 946.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1196.8ms
# Speed: 3.2ms preprocess, 1196.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1162.4ms
# Speed: 3.1ms preprocess, 1162.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 806.0ms
# Speed: 4.8ms preprocess, 806.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1145.7ms
# Speed: 3.1ms preprocess, 1145.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 879.7ms
# Speed: 1.8ms preprocess, 879.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 981.6ms
# Speed: 3.9ms preprocess, 981.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1011.5ms
# Speed: 2.1ms preprocess, 1011.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 896.2ms
# Speed: 2.6ms preprocess, 896.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed 340 frames...
#
# 0: 384x640 14 players, 1167.7ms
# Speed: 2.2ms preprocess, 1167.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1020.3ms
# Speed: 4.3ms preprocess, 1020.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 913.6ms
# Speed: 3.5ms preprocess, 913.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1196.1ms
# Speed: 1.9ms preprocess, 1196.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 886.9ms
# Speed: 1.6ms preprocess, 886.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 989.9ms
# Speed: 2.9ms preprocess, 989.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1076.6ms
# Speed: 2.0ms preprocess, 1076.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 878.9ms
# Speed: 1.6ms preprocess, 878.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1027.5ms
# Speed: 4.1ms preprocess, 1027.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1108.4ms
# Speed: 3.1ms preprocess, 1108.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 350 frames...
#
# 0: 384x640 13 players, 931.6ms
# Speed: 3.0ms preprocess, 931.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1063.6ms
# Speed: 3.0ms preprocess, 1063.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1042.0ms
# Speed: 2.2ms preprocess, 1042.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 934.3ms
# Speed: 2.8ms preprocess, 934.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1070.7ms
# Speed: 2.6ms preprocess, 1070.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1116.4ms
# Speed: 3.3ms preprocess, 1116.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 993.6ms
# Speed: 2.0ms preprocess, 993.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1115.3ms
# Speed: 4.7ms preprocess, 1115.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1399.2ms
# Speed: 2.9ms preprocess, 1399.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1226.1ms
# Speed: 2.0ms preprocess, 1226.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 360 frames...
#
# 0: 384x640 15 players, 1192.6ms
# Speed: 2.6ms preprocess, 1192.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1196.2ms
# Speed: 2.4ms preprocess, 1196.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1161.0ms
# Speed: 2.5ms preprocess, 1161.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1256.5ms
# Speed: 2.2ms preprocess, 1256.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 956.6ms
# Speed: 4.1ms preprocess, 956.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1011.3ms
# Speed: 1.9ms preprocess, 1011.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1243.0ms
# Speed: 3.1ms preprocess, 1243.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1001.7ms
# Speed: 3.0ms preprocess, 1001.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 955.8ms
# Speed: 1.8ms preprocess, 955.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1064.1ms
# Speed: 2.0ms preprocess, 1064.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed 370 frames...
#
# 0: 384x640 12 players, 1302.9ms
# Speed: 2.4ms preprocess, 1302.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1155.0ms
# Speed: 5.6ms preprocess, 1155.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1183.9ms
# Speed: 3.1ms preprocess, 1183.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1212.9ms
# Speed: 2.3ms preprocess, 1212.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1207.2ms
# Speed: 2.7ms preprocess, 1207.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Video saved.
